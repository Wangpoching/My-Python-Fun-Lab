# %% [markdown]
# #                                               ** 期末專題構想 **
# ## 主題: 女性年齡辨識
# ## 現在的美妝與微整型風氣盛行，導致女性的實際年齡變成了一個謎，所以想要做一個可以辨識女性年齡的工具。

# %% [markdown]
# ## 關於我想取得訓練資料的地方是 Tinder，因為用戶有一億人 ，而且有附照片與年齡

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image
fand = Image.open('Tinder.png')
plt.imshow(fand)

# %% [markdown]
# ### 大概是這個感覺

# %% [markdown]
# ## 至於要如何把照片Input呢?
# ### 目前的構想是使用Image J 的外掛

# %% [markdown]
# ### https://youtu.be/jb1mW8crpeE

# %% [markdown]
# ### 參考這個外掛這樣可以畫樣線來取得R G B 值
